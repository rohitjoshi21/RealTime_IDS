# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import joblib

# %%
# !gdown 'https://drive.google.com/uc?id=1AjWeHutvCSHCfB_si95rgF3904cuymxq'
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1AjWeHutvCSHCfB_si95rgF3904cuymxq
# From (redirected): https://drive.google.com/uc?id=1AjWeHutvCSHCfB_si95rgF3904cuymxq&confirm=t&uuid=7aa90f85-31db-4936-8e21-84da4aae0033
# To: /mnt/WorkingDrive/Automated-Intrusion-Detection-System-/notebook/out.csv
# 100%|████████████████████████████████████████| 110M/110M [00:11<00:00, 9.80MB/s]

# %%
df1 = pd.read_csv('out.csv')

# %%
df1['Label'].value_counts()
# Out:
# Label
# BENIGN         100000
# DoS             80000
# PortScan        75000
# DDoS            65000
# Brute Force     13835
# Web Attack       2180
# Other            2013
# Name: count, dtype: int64

# %%
df1.head()
# Out:
#    Destination Port  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0                80        5185118                  7                       7
# 1                80        5057374                 10                       7
# 2                80             81                  1                       1
# 3                80        5271123                  7                       5
# 4                80        5020638                  7                       4
#
#    Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                         1022                         2321
# 1                          736                         9880
# 2                            0                            0
# 3                          969                         1430
# 4                          973                         1430
#
#    Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# 0                    372                      0              146.000000
# 1                    395                      0               73.600000
# 2                      0                      0                0.000000
# 3                    561                      0              138.428571
# 4                    565                      0              139.000000
#
#    Fwd Packet Length Std  ...  min_seg_size_forward  Active Mean  Active Std  \
# 0             184.078788  ...                    32          0.0         0.0
# 1             155.683582  ...                    32          0.0         0.0
# 2               0.000000  ...                    32          0.0         0.0
# 3             240.502153  ...                    32          0.0         0.0
# 4             241.675402  ...                    32          0.0         0.0
#
#    Active Max  Active Min  Idle Mean  Idle Std  Idle Max  Idle Min       Label
# 0           0           0        0.0       0.0         0         0  Web Attack
# 1           0           0        0.0       0.0         0         0  Web Attack
# 2           0           0        0.0       0.0         0         0  Web Attack
# 3           0           0        0.0       0.0         0         0  Web Attack
# 4           0           0        0.0       0.0         0         0  Web Attack
#
# [5 rows x 71 columns]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df1['Label'] = le.fit_transform(df1['Label'])

# %%
df1.head()
# Out:
#    Destination Port  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0                80        5185118                  7                       7
# 1                80        5057374                 10                       7
# 2                80             81                  1                       1
# 3                80        5271123                  7                       5
# 4                80        5020638                  7                       4
#
#    Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                         1022                         2321
# 1                          736                         9880
# 2                            0                            0
# 3                          969                         1430
# 4                          973                         1430
#
#    Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# 0                    372                      0              146.000000
# 1                    395                      0               73.600000
# 2                      0                      0                0.000000
# 3                    561                      0              138.428571
# 4                    565                      0              139.000000
#
#    Fwd Packet Length Std  ...  min_seg_size_forward  Active Mean  Active Std  \
# 0             184.078788  ...                    32          0.0         0.0
# 1             155.683582  ...                    32          0.0         0.0
# 2               0.000000  ...                    32          0.0         0.0
# 3             240.502153  ...                    32          0.0         0.0
# 4             241.675402  ...                    32          0.0         0.0
#
#    Active Max  Active Min  Idle Mean  Idle Std  Idle Max  Idle Min  Label
# 0           0           0        0.0       0.0         0         0      6
# 1           0           0        0.0       0.0         0         0      6
# 2           0           0        0.0       0.0         0         0      6
# 3           0           0        0.0       0.0         0         0      6
# 4           0           0        0.0       0.0         0         0      6
#
# [5 rows x 71 columns]

# %%
from sklearn.preprocessing import StandardScaler
#Scaling every column in the dataframe
scaler = StandardScaler()
df1.iloc[:, :-1] = pd.DataFrame(scaler.fit_transform(df1.iloc[:, :-1]), columns=df1.iloc[:, :-1].columns)
# Out:
# /tmp/ipykernel_23677/745182219.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        -0.356131
# 1        -0.356131
# 2        -0.356131
# 3        -0.356131
# 4        -0.356131
#             ...
# 338023   -0.356131
# 338024   -0.356131
# 338025   -0.356131
# 338026   -0.356131
# 338027   -0.356131
# Name: Destination Port, Length: 338028, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :-1] = pd.DataFrame(scaler.fit_transform(df1.iloc[:, :-1]), columns=df1.iloc[:, :-1].columns)
# /tmp/ipykernel_23677/745182219.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        -0
flag Count, Length: 338028, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :-1] = pd.DataFrame(scaler.fit_transform(df1.iloc[:, :-1]), columns=df1.iloc[:, :-1].columns)
# /tmp/ipykernel_23677/745182219.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        -0.220684
# 1        -0.220684
# 2         4.531356
# 3        -0.220684
# 4        -0.220684
#             ...
# 338023   -0.220684
# 338024   -0.220684
# 338025   -0.220684
# 338026   -0.220684
# 338027   -0.220684
# Name: URG Flag Count, Length: 338028, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :-1] = pd.DataFrame(scaler.fit_transform(df1.iloc[:, :-1]), columns=df1.iloc[:, :-1].columns)
# /tmp/ipykernel_23677/745182219.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        -0.006662
# 1        -0.006662
# 2        -0.006662
# 3        -0.006662
# 4        -0.006662
#             ...
# 338023   -0.006662
# 338024   -0.006662
# 338025   -0.006662
# 338026   -0.006662
# 338027   -0.006662
# Name: CWE Flag Count, Length: 338028, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :-1] = pd.DataFrame(scaler.fit_transform(df1.iloc[:, :-1]), columns=df1.iloc[:, :-1].columns)
# /tmp/ipykernel_23677/745182219.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        -0.010742
# 1        -0.010742
# 2        -0.010742
# 3        -0.010742
# 4        -0.010742
#             ...
# 338023   -0.010742
# 338024   -0.010742
# 338025   -0.010742
# 338026   -0.010742
# 338027   -0.010742
# Name: ECE Flag Count, Length: 338028, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :-1] = pd.DataFrame(scaler.fit_transform(df1.iloc[:, :-1]), columns=df1.iloc[:, :-1].columns)
# /tmp/ipykernel_23677/745182219.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         0.538559
# 1        -1.083250
# 2         0.538559
# 3        -1.083250
# 4        -1.083250
#             ...
# 338023    0.538559
# 338024   -1.083250
# 338025   -1.083250
# 338026    0.538559
# 338027    2.160368
# Name: Down/Up Ratio, Length: 338028, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :-1] = pd.DataFrame(scaler.fit_transform(df1.iloc[:, :-1]), columns=df1.iloc[:, :-1].columns)
# /tmp/ipykernel_23677/745182219.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         0.001740
# 1         0.001769
# 2         0.001680
# 3         0.001740
# 4         0.001740
#             ...
# 338023    0.001692
# 338024    0.001694
# 338025    0.001694
# 338026    0.001692
# 338027    0.001692
# Name: Fwd Header Length.1, Length: 338028, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :-1] = pd.DataFrame(scaler.fit_transform(df1.iloc[:, :-1]), columns=df1.iloc[:, :-1].columns)
# /tmp/ipykernel_23677/745182219.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         0.001356
# 1         0.007455
# 2        -0.010844
# 3         0.001356
# 4         0.001356
#             ...
# 338023   -0.006777
# 338024   -0.004744
# 338025   -0.004744
# 338026   -0.006777
# 338027   -0.006777
# Name: Subflow Fwd Packets, Length: 338028, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :-1] = pd.DataFrame(scaler.fit_transform(df1.iloc[:, :-1]), columns=df1.iloc[:, :-1].columns)
# /tmp/ipykernel_23677/745182219.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         0.026328
# 1         0.014410
# 2        -0.016263
# 3         0.024120
# 4         0.024286
#             ...
# 338023   -0.015180
# 338024   -0.015263
# 338025   -0.015263
# 338026   -0.015180
# 338027   -0.015180
# Name: Subflow Fwd Bytes, Length: 338028, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :-1] = pd.DataFrame(scaler.fit_transform(df1.iloc[:, :-1]), columns=df1.iloc[:, :-1].columns)
# /tmp/ipykernel_23677/745182219.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         0.000841
# 1         0.000841
# 2        -0.008196
# 3        -0.002171
# 4        -0.003677
#             ...
# 338023   -0.003677
# 338024   -0.009702
# 338025   -0.009702
# 338026   -0.002171
# 338027   -0.000665
# Name: Subflow Bwd Packets, Length: 338028, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :-1] = pd.DataFrame(scaler.fit_transform(df1.iloc[:, :-1]), columns=df1.iloc[:, :-1].columns)
# /tmp/ipykernel_23677/745182219.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        -0.004998
# 1         0.000066
# 2        -0.006553
# 3        -0.005595
# 4        -0.005595
#             ...
# 338023    0.001218
# 338024   -0.006553
# 338025   -0.006553
# 338026    0.001222
# 338027    0.001218
# Name: Subflow Bwd Bytes, Length: 338028, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :-1] = pd.DataFrame(scaler.fit_transform(df1.iloc[:, :-1]), columns=df1.iloc[:, :-1].columns)
# /tmp/ipykernel_23677/745182219.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         1.653144
# 1         1.653144
# 2        -0.585746
# 3         1.653144
# 4         1.653144
#             ...
# 338023    0.027337
# 338024   -0.586829
# 338025   -0.586829
# 338026    0.027337
# 338027    0.027337
# Name: Init_Win_bytes_forward, Length: 338028, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :-1] = pd.DataFrame(scaler.fit_transform(df1.iloc[:, :-1]), columns=df1.iloc[:, :-1].columns)
# /tmp/ipykernel_23677/745182219.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        -0.132204
# 1        -0.133770
# 2        -0.132204
# 3        -0.133596
# 4        -0.133596
#             ...
# 338023   -0.136206
# 338024   -0.176225
# 338025   -0.176225
# 338026   -0.136206
# 338027   -0.136206
# Name: Init_Win_bytes_backward, Length: 338028, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :-1] = pd.DataFrame(scaler.fit_transform(df1.iloc[:, :-1]), columns=df1.iloc[:, :-1].columns)
# /tmp/ipykernel_23677/745182219.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        -0.000748
# 1        -0.003222
# 2        -0.008171
# 3        -0.003222
# 4        -0.003222
#             ...
# 338023   -0.003222
# 338024   -0.000748
# 338025   -0.000748
# 338026   -0.003222
# 338027   -0.003222
# Name: act_data_pkt_fwd, Length: 338028, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :-1] = pd.DataFrame(scaler.fit_transform(df1.iloc[:, :-1]), columns=df1.iloc[:, :-1].columns)
# /tmp/ipykernel_23677/745182219.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         0.001755
# 1         0.001755
# 2         0.001755
# 3         0.001755
# 4         0.001755
#             ...
# 338023    0.001672
# 338024    0.001672
# 338025    0.001672
# 338026    0.001672
# 338027    0.001672
# Name: min_seg_size_forward, Length: 338028, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :-1] = pd.DataFrame(scaler.fit_transform(df1.iloc[:, :-1]), columns=df1.iloc[:, :-1].columns)
# /tmp/ipykernel_23677/745182219.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        -0.146417
# 1        -0.146417
# 2        -0.146417
# 3        -0.146417
# 4        -0.146417
#             ...
# 338023   -0.146417
# 338024   -0.136945
# 338025   -0.145211
# 338026   -0.146417
# 338027   -0.146417
# Name: Active Max, Length: 338028, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :-1] = pd.DataFrame(scaler.fit_transform(df1.iloc[:, :-1]), columns=df1.iloc[:, :-1].columns)
# /tmp/ipykernel_23677/745182219.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        -0.123296
# 1        -0.123296
# 2        -0.123296
# 3        -0.123296
# 4        -0.123296
#             ...
# 338023   -0.123296
# 338024   -0.110369
# 338025   -0.121649
# 338026   -0.123296
# 338027   -0.123296
# Name: Active Min, Length: 338028, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :-1] = pd.DataFrame(scaler.fit_transform(df1.iloc[:, :-1]), columns=df1.iloc[:, :-1].columns)
# /tmp/ipykernel_23677/745182219.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        -0.494804
# 1        -0.494804
# 2        -0.494804
# 3        -0.494804
# 4        -0.494804
#             ...
# 338023   -0.494804
# 338024   -0.228310
# 338025   -0.248808
# 338026   -0.494804
# 338027   -0.494804
# Name: Idle Max, Length: 338028, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :-1] = pd.DataFrame(scaler.fit_transform(df1.iloc[:, :-1]), columns=df1.iloc[:, :-1].columns)
# /tmp/ipykernel_23677/745182219.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        -0.462497
# 1        -0.462497
# 2        -0.462497
# 3        -0.462497
# 4        -0.462497
#             ...
# 338023   -0.462497
# 338024   -0.184656
# 338025   -0.206027
# 338026   -0.462497
# 338027   -0.462497
# Name: Idle Min, Length: 338028, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :-1] = pd.DataFrame(scaler.fit_transform(df1.iloc[:, :-1]), columns=df1.iloc[:, :-1].columns)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 338028 entries, 0 to 338027
# Data columns (total 71 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Destination Port             338028 non-null  float64
#  1   Flow Duration                338028 non-null  float64
#  2   Total Fwd Packets            338028 non-null  float64
#  3   Total Backward Packets       338028 non-null  float64
#  4   Total Length of Fwd Packets  338028 non-null  float64
#  5   Total Length of Bwd Packets  338028 non-null  float64
#  6   Fwd Packet Length Max        338028 non-null  float64
#  7   Fwd Packet Length Min        338028 non-null  float64
#  8   Fwd Packet Length Mean       338028 non-null  float64
#  9   Fwd Packet Length Std        338028 non-null  float64
#  10  Bwd Packet Length Max        338028 non-null  float64
#  11  Bwd Packet Length Min        338028 non-null  float64
#  12  Bwd Packet Length Mean       338028 non-null  float64
#  13  Bwd Packet Length Std        338028 non-null  float64
#  14  Flow Bytes/s                 338028 non-null  float64
#  15  Flow Packets/s               338028 non-null  float64
#  16  Flow IAT Mean                338028 non-null  float64
#  17  Flow IAT Std                 338028 non-null  float64
#  18  Flow IAT Max                 338028 non-null  float64
#  19  Flow IAT Min                 338028 non-null  float64
#  20  Fwd IAT Total                338028 non-null  float64
#  21  Fwd IAT Mean                 338028 non-null  float64
#  22  Fwd IAT Std                  338028 non-null  float64
#  23  Fwd IAT Max                  338028 non-null  float64
#  24  Fwd IAT Min                  338028 non-null  float64
#  25  Bwd IAT Total                338028 non-null  float64
#  26  Bwd IAT Mean                 338028 non-null  float64
#  27  Bwd IAT Std                  338028 non-null  float64
#  28  Bwd IAT Max                  338028 non-null  float64
#  29  Bwd IAT Min                  338028 non-null  float64
#  30  Fwd PSH Flags                338028 non-null  float64
#  31  Fwd URG Flags                338028 non-null  float64
#  32  Fwd Header Length            338028 non-null  float64
#  33  Bwd Header Length            338028 non-null  float64
#  34  Fwd Packets/s                338028 non-null  float64
#  35  Bwd Packets/s                338028 non-null  float64
#  36  Min Packet Length            338028 non-null  float64
#  37  Max Packet Length            338028 non-null  float64
#  38  Packet Length Mean           338028 non-null  float64
#  39  Packet Length Std            338028 non-null  float64
#  40  Packet Length Variance       338028 non-null  float64
#  41  FIN Flag Count               338028 non-null  float64
#  42  SYN Flag Count               338028 non-null  float64
#  43  RST Flag Count               338028 non-null  float64
#  44  PSH Flag Count               338028 non-null  float64
#  45  ACK Flag Count               338028 non-null  float64
#  46  URG Flag Count               338028 non-null  float64
#  47  CWE Flag Count               338028 non-null  float64
#  48  ECE Flag Count               338028 non-null  float64
#  49  Down/Up Ratio                338028 non-null  float64
#  50  Average Packet Size          338028 non-null  float64
#  51  Avg Fwd Segment Size         338028 non-null  float64
#  52  Avg Bwd Segment Size         338028 non-null  float64
#  53  Fwd Header Length.1          338028 non-null  float64
#  54  Subflow Fwd Packets          338028 non-null  float64
#  55  Subflow Fwd Bytes            338028 non-null  float64
#  56  Subflow Bwd Packets          338028 non-null  float64
#  57  Subflow Bwd Bytes            338028 non-null  float64
#  58  Init_Win_bytes_forward       338028 non-null  float64
#  59  Init_Win_bytes_backward      338028 non-null  float64
#  60  act_data_pkt_fwd             338028 non-null  float64
#  61  min_seg_size_forward         338028 non-null  float64
#  62  Active Mean                  338028 non-null  float64
#  63  Active Std                   338028 non-null  float64
#  64  Active Max                   338028 non-null  float64
#  65  Active Min                   338028 non-null  float64
#  66  Idle Mean                    338028 non-null  float64
#  67  Idle Std                     338028 non-null  float64
#  68  Idle Max                     338028 non-null  float64
#  69  Idle Min                     338028 non-null  float64
#  70  Label                        338028 non-null  int64
# dtypes: float64(70), int64(1)
# memory usage: 183.1 MB

# %%
correlation = df1.select_dtypes(include='float64').corr().abs()

# %%
correlation
# Out:
#                              Destination Port  Flow Duration  \
# Destination Port                     1.000000       0.173457
# Flow Duration                        0.173457       1.000000
# Total Fwd Packets                    0.003341       0.014204
# Total Backward Packets               0.002772       0.011966
# Total Length of Fwd Packets          0.002319       0.019884
# ...                                       ...            ...
# Active Min                           0.033840       0.157829
# Idle Mean                            0.157827       0.911839
# Idle Std                             0.038415       0.304592
# Idle Max                             0.159043       0.931501
# Idle Min                             0.152792       0.869429
#
#                              Total Fwd Packets  Total Backward Packets  \
# Destination Port                      0.003341                0.002772
# Flow Duration                         0.014204                0.011966
# Total Fwd Packets                     1.000000                0.999322
# Total Backward Packets                0.999322                1.000000
# Total Length of Fwd Packets           0.134814                0.112214
# ...                                        ...                     ...
# Active Min                            0.006440                0.005684
# Idle Mean                             0.001808                0.000709
# Idle Std                              0.001258                0.000265
# Idle Max                              0.001986                0.000730
# Idle Min                              0.001593                0.000653
#
#                              Total Length of Fwd Packets  \
# Destination Port                                0.002319
# Flow Duration                                   0.019884
# Total Fwd Packets                               0.134814
# Total Backward Packets                          0.112214
# Total Length of Fwd Packets                     1.000000
# ...                                                  ...
# Active Min                                      0.017075
# Idle Mean                                       0.003598
# Idle Std                                        0.004954
# Idle Max                                        0.004693
# Idle Min                                        0.002723
#
#                              Total Length of Bwd Packets  \
# Destination Port                                0.002300
# Flow Duration                                   0.010219
# Total Fwd Packets                               0.995791
# Total Backward Packets                          0.997671
# Total Length of Fwd Packets                     0.091812
# ...                                                  ...
# Active Min                                      0.004017
# Idle Mean                                       0.000917
# Idle Std                                        0.000352
# Idle Max                                        0.000935
# Idle Min                                        0.000862
#
#                              Fwd Packet Length Max  Fwd Packet Length Min  \
# Destination Port                          0.070548               0.002323
# Flow Duration                             0.267825               0.078487
# Total Fwd Packets                         0.008768               0.001446
# Total Backward Packets                    0.007752               0.001201
# Total Length of Fwd Packets               0.069613               0.002583
# ...                                            ...                    ...
# Active Min                                0.043730               0.018059
# Idle Mean                                 0.206221               0.069810
# Idle Std                                  0.050146               0.026936
# Idle Max                                  0.207381               0.071890
# Idle Min                                  0.199271               0.065985
#
#                              Fwd Packet Length Mean  Fwd Packet Length Std  \
# Destination Port                           0.111927               0.091224
# Flow Duration                              0.144598               0.262118
# Total Fwd Packets                          0.002731               0.002920
# Total Backward Packets                     0.001832               0.002367
# Total Length of Fwd Packets                0.084084               0.055419
# ...                                             ...                    ...
# Active Min                                 0.036524               0.040802
# Idle Mean                                  0.116510               0.224297
# Idle Std                                   0.050183               0.057963
# Idle Max                                   0.121611               0.226185
# Idle Min                                   0.109211               0.216465
#
#                              ...  act_data_pkt_fwd  min_seg_size_forward  \
# Destination Port             ...          0.002489              0.000061
# Flow Duration                ...          0.009217              0.002018
# Total Fwd Packets            ...          0.864817              0.000996
# Total Backward Packets       ...          0.861594              0.000016
# Total Length of Fwd Packets  ...          0.155389              0.001595
# ...                          ...               ...                   ...
# Active Min                   ...          0.006128              0.000211
# Idle Mean                    ...          0.000062              0.000190
# Idle Std                     ...          0.001417              0.001270
# Idle Max                     ...          0.000318              0.000273
# Idle Min                     ...          0.000181              0.000344
#
#                              Active Mean  Active Std  Active Max  Active Min  \
# Destination Port                0.039460    0.026464    0.043751    0.033840
# Flow Duration                   0.194571    0.159479    0.234263    0.157829
# Total Fwd Packets               0.009120    0.010436    0.013031    0.006440
# Total Backward Packets          0.007076    0.006427    0.009243    0.005684
# Total Length of Fwd Packets     0.045570    0.103184    0.095179    0.017075
# ...                                  ...         ...         ...         ...
# Active Min                      0.942911    0.014670    0.741115    1.000000
# Idle Mean                       0.120972    0.003998    0.092346    0.127028
# Idle Std                        0.060806    0.087218    0.069513    0.033198
# Idle Max                        0.136279    0.035304    0.112585    0.132084
# Idle Min                        0.110252    0.010857    0.079782    0.120931
#
#                              Idle Mean  Idle Std  Idle Max  Idle Min
# Destination Port              0.157827  0.038415  0.159043  0.152792
# Flow Duration                 0.911839  0.304592  0.931501  0.869429
# Total Fwd Packets             0.001808  0.001258  0.001986  0.001593
# Total Backward Packets        0.000709  0.000265  0.000730  0.000653
# Total Length of Fwd Packets   0.003598  0.004954  0.004693  0.002723
# ...                                ...       ...       ...       ...
# Active Min                    0.127028  0.033198  0.132084  0.120931
# Idle Mean                     1.000000  0.131918  0.987541  0.987256
# Idle Std                      0.131918  1.000000  0.284251  0.027347
# Idle Max                      0.987541  0.284251  1.000000  0.950239
# Idle Min                      0.987256  0.027347  0.950239  1.000000
#
# [70 rows x 70 columns]

# %%
upper_triangle = correlation.where(np.triu(np.ones(correlation.shape), k=1).astype(bool))

to_drop = [column for column in upper_triangle.columns if any(upper_triangle[column] > 0.95)]

to_drop.append('Destination Port')

df = df1.drop(columns=to_drop)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 338028 entries, 0 to 338027
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Flow Duration                338028 non-null  float64
#  1   Total Fwd Packets            338028 non-null  float64
#  2   Total Length of Fwd Packets  338028 non-null  float64
#  3   Fwd Packet Length Max        338028 non-null  float64
#  4   Fwd Packet Length Min        338028 non-null  float64
#  5   Fwd Packet Length Mean       338028 non-null  float64
#  6   Bwd Packet Length Max        338028 non-null  float64
#  7   Bwd Packet Length Min        338028 non-null  float64
#  8   Flow Bytes/s                 338028 non-null  float64
#  9   Flow Packets/s               338028 non-null  float64
#  10  Flow IAT Mean                338028 non-null  float64
#  11  Flow IAT Std                 338028 non-null  float64
#  12  Flow IAT Min                 338028 non-null  float64
#  13  Fwd IAT Mean                 338028 non-null  float64
#  14  Fwd IAT Min                  338028 non-null  float64
#  15  Bwd IAT Total                338028 non-null  float64
#  16  Bwd IAT Mean                 338028 non-null  float64
#  17  Bwd IAT Std                  338028 non-null  float64
#  18  Bwd IAT Max                  338028 non-null  float64
#  19  Bwd IAT Min                  338028 non-null  float64
#  20  Fwd PSH Flags                338028 non-null  float64
#  21  Fwd URG Flags                338028 non-null  float64
#  22  Fwd Header Length            338028 non-null  float64
#  23  Fwd Packets/s                338028 non-null  float64
#  24  Bwd Packets/s                338028 non-null  float64
#  25  Min Packet Length            338028 non-null  float64
#  26  Packet Length Variance       338028 non-null  float64
#  27  FIN Flag Count               338028 non-null  float64
#  28  RST Flag Count               338028 non-null  float64
#  29  PSH Flag Count               338028 non-null  float64
#  30  ACK Flag Count               338028 non-null  float64
#  31  URG Flag Count               338028 non-null  float64
#  32  Down/Up Ratio                338028 non-null  float64
#  33  Init_Win_bytes_forward       338028 non-null  float64
#  34  Init_Win_bytes_backward      338028 non-null  float64
#  35  act_data_pkt_fwd             338028 non-null  float64
#  36  Active Mean                  338028 non-null  float64
#  37  Active Std                   338028 non-null  float64
#  38  Active Max                   338028 non-null  float64
#  39  Active Min                   338028 non-null  float64
#  40  Idle Std                     338028 non-null  float64
#  41  Label                        338028 non-null  int64
# dtypes: float64(41), int64(1)
# memory usage: 108.3 MB

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.iloc[:, :-1]
y = df.iloc[:,-1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

basemodel = LogisticRegression(max_iter=20000).fit(X_train, y_train)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rmodel = RandomForestClassifier(n_estimators=100).fit(X_train, y_train)

# %%
y_pred = rmodel.predict(X_test)

# %%
import joblib

joblib.dump(smodel, 'svm_model.joblib')
# Out:
# ['svm_model.joblib']

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

# y_pred = basemodel.predict(X_test)

rec = recall_score(y_test, y_pred, average=None)
pre = precision_score(y_test, y_pred, average=None)
f1 = f1_score(y_test, y_pred, average=None)
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
print(f'Recall: {rec}')
print(f'Precision: {pre}')
print(f'F1 Score: {f1}')
# Out:
# Accuracy: 0.9985947992781706
# Recall: [0.99814889 0.99821683 0.99961686 0.99925271 0.9547619  0.9995955
#  0.97571744]
# Precision: [0.99745025 0.99964286 0.99969346 0.9988173  0.9756691  0.9995955
#  0.99103139]
# F1 Score: [0.99779945 0.99892934 0.99965516 0.99903496 0.96510229 0.9995955
#  0.98331479]

# %% [markdown]
# # SVM

# %%
from sklearn.svm import LinearSVC

# %%
smodel = LinearSVC()
smodel.fit(X_train,y_train)
# Out:
# /home/riemann/.pyenv/versions/normal/lib/python3.10/site-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# LinearSVC()

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

y_pred = smodel.predict(X_test)

rec = recall_score(y_test, y_pred, average=None)
pre = precision_score(y_test, y_pred, average=None)
f1 = f1_score(y_test, y_pred, average=None)
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
print(f'Recall: {rec}')
print(f'Precision: {pre}')
print(f'F1 Score: {f1}')
# Out:
# Accuracy: 0.9207170961157294
# Recall: [0.82483726 0.76368774 0.99823145 0.98060439 0.00238095 0.99819796
#  0.        ]
# Precision: [0.91760905 0.76422764 0.97272591 0.87877768 0.07142857 0.96112075
#  0.        ]
# F1 Score: [0.86875346 0.7639576  0.98531365 0.92690283 0.00460829 0.97930854
#  0.        ]
